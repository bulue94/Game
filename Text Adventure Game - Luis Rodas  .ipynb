# %%
import time
from random import randint

def header():
    print('\n')
    print('-'*80)
    print('\n')
    time.sleep(1)

################################################################################################################

def menu():
    global close
    
    close = '''
                    ⠀⠀⠀⠀⣠⣶⡾⠏⠉⠙⠳⢦⡀⠀⠀⠀⢠⠞⠉⠙⠲⡀⠀
                    ⠀⠀⠀⣴⠿⠏⠀⠀⠀⠀⠀⠀⢳⡀⠀⡏⠀⠀⠀⠀⠀⢷
                    ⠀⠀⢠⣟⣋⡀⢀⣀⣀⡀⠀⣀⡀⣧⠀⢸⠀⠀⠀⠀⠀ ⡇
                    ⠀⠀⢸⣯⡭⠁⠸⣛⣟⠆⡴⣻⡲⣿⠀⣸⠀⠀OK⠀ ⡇
                    ⠀⠀⣟⣿⡭⠀⠀⠀⠀⠀⢱⠀⠀⣿⠀⢹⠀⠀⠀⠀⠀ ⡇
                    ⠀⠀⠙⢿⣯⠄⠀⠀⠀⢀⡀⠀⠀⡿⠀⠀⡇⠀⠀⠀⠀⡼
                    ⠀⠀⠀⠀⠹⣶⠆⠀⠀⠀⠀⠀⡴⠃⠀⠀⠘⠤⣄⣠⠞⠀
                    ⠀⠀⠀⠀⠀⢸⣷⡦⢤⡤⢤⣞⣁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                    ⠀⠀⢀⣤⣴⣿⣏⠁⠀⠀⠸⣏⢯⣷⣖⣦⡀⠀⠀⠀⠀⠀⠀
                    ⢀⣾⣽⣿⣿⣿⣿⠛⢲⣶⣾⢉⡷⣿⣿⠵⣿⠀⠀⠀⠀⠀⠀
                    ⣼⣿⠍⠉⣿⡭⠉⠙⢺⣇⣼⡏⠀⠀⠀⣄⢸⠀⠀⠀⠀⠀⠀
                    ⣿⣿⣧⣀⣿.........⣀⣰⣏⣘⣆⣀'''
    
    while True:
        q = 0

        while q != 1:
            q = 0
            menu = input('''\
\t\t███╗   ███╗███████╗███╗   ██╗██╗   ██╗
\t\t████╗ ████║██╔════╝████╗  ██║██║   ██║
\t\t██╔████╔██║█████╗  ██╔██╗ ██║██║   ██║
\t\t██║╚██╔╝██║██╔══╝  ██║╚██╗██║██║   ██║
\t\t██║ ╚═╝ ██║███████╗██║ ╚████║╚██████╔╝
\t\t╚═╝     ╚═╝╚══════╝╚═╝  ╚═══╝ ╚═════╝ 
                                      

\t\t\t   1) Instructions
\t\t\t   2) Start Game
\t\t\t   3) Credits
\t\t\t   4) Quit\n\n\t\t-->''')
            if "1" in menu or "instructions" in menu.lower():
                q +=1
            if "2" in menu or "start game" in menu.lower():
                q +=1
            if "3" in menu or "credits" in menu.lower():
                q +=1
            if "4" in menu or "quit" in menu.lower():
                q +=1
            if q == 1:
                break
            else:
                print('\n\t\tSelect one of the four options\n')


        if "1" in menu or "instructions" in menu.lower():
            header()
            print('''
\tThis game follows your adventure inside the ‘One Punch Man’ 
\tworld, were you begin by doing your tests to enter the Hero 
\tAssociation and start fighting the crime while getting a 
\tpaycheck. After this you will face the different scenarios 
\tthat a hero may see during a normal day.
\n\tThe purpose of the game is to present some characters of the 
\tanime to the users and to appreciate the comedy presented in 
\tthe show. Most of the script for this game is based on 
\tthe Episode 1 of Season 1.
''')
            header()
        elif "2" in menu or "start game" in menu.lower():
            header()
            start()
            break
        elif "3" in menu or "credits" in menu.lower():
            header()
            print('''
\tThis game was created by Luis Pedro Rodas for the python
\tclass at Hult during the MBAN DD program.\n
\tThe story is based on an anime called 'One Punch Man', and 
\tit's the story of this bald hero that lost his hair when he
\tbecame the strongest man in the universe.\n
\tHis aim was to become a hero to defeat the evil in the world
\tbut know he defeats everyone with just one punch, so he lost
\tthe hunger for fight.
\n\tMore detailed information about the anime in the following link:
\t\thttps://onepunchman.fandom.com/wiki/One-Punch_Man_Wiki''')
            header()
        elif "4" in menu or "quit" in menu.lower():
            header()
            print(close)
            break
        else:
            print ("BUG ALERT!!!!, let's call Spider-Man\n")
    

################################################################################################################
            
def start ():
    global name
    global special_move
    global rank
    
    print('''
\t\t>>>>> HERO TEST LOCATION 6 <<<<<\n\n
Recruiter:
\tCandidates, please form two lines for registration...''')
    
    input('\n\t\t<Press any key to continue>\n\t')
    
    name = input(prompt = '''
Recruiter:
\tWe are glad you came, it's always great to see a bunch of
\tpeople come to be part of the Hero Assosiation... well I
\tshould't talk that much.
\tWhat's your Superhero name?\t--> ''')
    
    time.sleep(0.2) 
    
    special_move = input(prompt =f'''
Recruiter:\n\t{name} mmmmm... interesting name for a Superhero.
\tNow plese tell us the name of your special attack...\t--> ''')
    
    time.sleep(0.2)
    
    print('''
Recruiter:
\tPerfect, we have all the information needed for your profile
\tso you can go and do both the written and fitness and tests''')
    
    header()
    tests()
    
################################################################################################################ 

def tests():
    points = 0
    
    print('''
\t\t>>>>> WRITTEN TEST <<<<<\n\n
Test recruiter:
\tWelcome eveyone, this test focus is to determine your
\treasoning during hero moments. Answer the following
\tquestions so you can move to your fitness test.''')
        
    input('\n\t\t<Press any key to continue>\n\t')
    
    answers_1 = ['people','justice','save','defend','humanity']
    
    question_1 = input(prompt ='''
\tWhat is your motivation for being a hero?\n\t--> ''')
    
    for item in answers_1:
        if item in question_1.lower():
                points +=4
        else:
            continue
    
    questions = ['If a Dragon level (highest level) monster appears in the city, what would you do?','How would you handle any collateral damage caused due to a fight with a monster?']
    
    answers_2 = [['request','reinforcement','evacuate','rescue'], ['pay','insurance','support','rebuild']]
    
    option = randint(0,1)
    
    question_2 = input(prompt =f'''
\t{questions[option]}
\t--> ''')
    
    for item in answers_2[option]:
        if item in question_2:
            points += 20
    
    print('''\n
Test recruiter:
\tNow go to the ground floor and the first door on your
\tright will be the entrange to the gym so you can be
\tdone with the fitness tests''')
    
    header()
   
    jumps = randint(30,90)
    
    print(f'''
\t\t>>>>> FITNESS TEST <<<<<\n\n
Fitness recruiter:
\tNext! side-to-side jumps for 30 seconds!
\tReady...
\tGo!
\t...
\t{name}, {jumps} jumps...
\t[writes down results]\n\n''')
    
    time.sleep(2)
    
    run = randint(210,270)
    
    print(f'''
Fitness recruiter:
\tNext! the 1,500 meter run. Go!
\t...
\t{name}, {run} seconds...
\t[writes down results]\n\n''')
    
    time.sleep(2)
    
    whack_a_mole = randint(115,180)
    
    print(f'''
Fitness recruiter:
\tWhack-a-Mole!
\t...
\t{name}, {whack_a_mole} points...
\t[writes down results]\n\n''')
    
    time.sleep(2)
    
    punch = randint(114000,200000)
    
    print(f'''
Fitness recruiter:
\tPunching machine!
\t...
\t{name}, {punch} units...
\t[writes down results]\n\n
\tOk! We are finally done, we'll send your result in 1 hour''')
    
    time.sleep(1)
    
    if points == 40:
        rank = 'A'
    elif points >= 4:
        rank = 'B'
    elif points == 0:
        rank = 'C'
    else:
        print('GG WP, theres something wrong here')

    print(f'''
Snek:
\tCongratulations {name} on passing, you've become a {rank}-Class hero.
\tNow it's time for you to go out there and defeat some monsters.''')
    
    input('\n\t\t<Press any key to continue>\n\t')
    
    header()
    
    fight()

################################################################################################################ 

def fight():
    monster = ['Save kids\' balloon','Garou','Carblante']
    
    description = ['My balloon is stuck in the branches of that tree','''The popular will win, the hated will lose, it\'s 
\tsuch a tragedy. Then I won\'t lose to anyone. I 
\twill become the strongest monster ever and 
\tchange this scenario''','I ate too much crab and transformed into this']

    opponent = randint(0,2)
    
    saitama = randint(1,5)
    
    print('\t\tTwo hours later...')
    
    time.sleep(1)
    
    print(f'''
Someone:
\tAaaaaaah!!!!!!
\n\n{name}:
\t...what's that scream?''')
    
    while True:
        action = input(prompt = '''
\tSelect one option:
\t\t- Go and be a hero
\t\t- Keep on going\n\t--> ''')
        if 'hero' in action.lower() and 'going' in action.lower():
            print('\n\n\tSelect just one option! Hurry someone may be on danger!\n')
        elif 'going' in action.lower():
            print('\n\tKeep walking\n')
            break
        elif 'hero' in action.lower():
            print('\n\t...approaching source of screams\n')
            break
        else:
            print('\n\n\tEnter a valid option\n')
            
    if 'hero' in action.lower():
        if opponent == 0:
            print(f'''
{name}:
\tWhy are you crying kid?...
\nKid:
\t{description[opponent]}
\n{name}:
\tCry no more, here is your new {rank}-Class hero to save
\tyour day! Take your balloon kid.
\t...it's awesome to be a hero!!''')
            print("monster_cell")
        elif opponent == 1:
            print(f'''
{monster[opponent]}:
\t{description[opponent]}''')
            time.sleep(1)
            print(f'''
{name}:
\tI'll show you my {special_move}, {monster[opponent]}, you shouldn't 
\tbe calling yourself monster unless you want trouble 
\twith heroes like me... [{name} attacks {monster[opponent]}]''')
            time.sleep(1)
            print(f'''
{monster[opponent]}:
\tHahahaha and that was your best attack? Now let me show 
\tyou how to fight, don't worry I'll kill you fast''')
            if saitama == 3:
                print('''
........................................................................    . .....................
,.......................................................................   . .......   ............
. ,.......................................................................         .  .............
..................................................................................             ....
.....*......................................../,,,,,,,,/............................   ......  ....
 .. ......................................../,,,,,,,,,,,.*.........................          ......
... ....,................................../,,,,,,,,,,,,..........................          .......
..........................................,,,,,*,,,,,,,,,,/.......................         ........
.......... ..............................,,,,,*..*,,,,,,,,/.................  .              ......
...........  ...........................*,(,,,,,,*,,/*.,,,..............                      .....
,,..........  ..........................(*,,,,,,,,,,,,,/,,..............        ..//...       .....
,,,,..........   ,.......................(/,,,,,,,,*,,,,,...............     ..//(((((//..   ......
,,,,,,.......... .. ,.....................#,,,,,,(/,,,,,*................ .../(((((((((((*.........
.,,,,,,,............   ,..............././/#,,,,,,,,,,,*..................//(((((((((((#(/.........
..,,*,,,,,.......... .. ............*,....*((/,,,,,,,/......############(//(((((((((((##/..........
...,,,,,,,,,,................,..,. *,,,,,,/*(*,,,,,,,,*,,,,#(((((#########((((((((((###/...........
....,,,,,,,,*,,,,,,......,..,... ,,,,,,,#,,,,,,,,,,,,,*,,,##%%%%%%%%%%%%#%%%#########(*............
......,,,,,,,,,,,,*...,,.,,....(,,,,,,/,,,,,,,,,,,,,,(,,,,%%%%%%%%%%%%&&&&&%%(((/*((/..............
......,,***.....,,....*,....,*(,,,,,,,,,,,,,,,,,,,,,,,,,,,%%%%%%&&&&&&&&*,,,...............,,,,,,,,
,,,,,,,,,,,,,.....,,,....,,**/,,,,,,,,,,,,,,,,,,,,,,///////&&&&&&&&%,...........,,,,,,,,,,,,,,,,,,,
..............,,*,,...,.,*/**,,,,,,,,,,///(###%%#(/////.....&&/...................,,,,,,,,,,,,,,,,,
..........,,,*/**,,...,*/****,,,,,,(//////////*(#//////*.............................,,,,,,,,,,,,,,
......,,***/**,,,,..**/*****(,,,,*/#/////////((/////(/,..................................,...,,,,,,
.,**/**/,,,,,,,,,,**/*******,,,,,,*/,////////(##/////*/............................................
,,,,,,,,,,,,,,,,***********(,,,,,,,,,//////////////(*,*............................................
,,,,,,,,,,,,,**/************,,,,,,,,///((((((((//(((/,/........... ... ............................
,,,,,,,,,,**(**************,,,,,,,,/((((((#(((((#(((/,,                      . ....................
,,,,,,,**(*****************,,,,,,,/((((((((((((((((((,,''') 
                print(f'''
\nSaitama:
\tI thought that you {monster[opponent]} would resist more than one punch
\tafter all that you said, this is so disapointing\n
{name}:
\tThanks you saved me! It's amazing how strong you are!\n
Saitama:
\tLet me make one thing clear! I'm not working as a hero because I 
\twant you morons to admire me! I do it because I want to!\n''')
                header()
                monster_cell()
            else:
                header()
                fail()
        elif opponent == 2:
            print(f'''
{monster[opponent]}:
\t{description[opponent]}''')
            time.sleep(1)
            print(f'''
{name}:
\tI'll show you my {special_move}, {monster[opponent]}, you shouldn't 
\tbe calling yourself monster unless you want trouble 
\twith heroes like me... [{name} attacks {monster[opponent]}]
\nCivilian:
\tLook this is {name} he saved us from the raging attack of {monster[opponent]}!
\n{name}:
\tThanks for your support people! I', just doing my job.\n''')
            header()
            monster_cell()
    else:
        print(f'''
{name}:
\tAnother hero will take care of that, I forgot to do the
\tgroceries and my mom will kill me if don't take them today\n''')
        header()
        monster_cell()
            
################################################################################################################            

def monster_cell():
    print('''
Monster:
\tHey! Hey! ok, know I got your attention, interested in
\becoming even stronger? I can get you some monster cells
\tthat will easily make you as stronger than a top A-Class 
\thero...   Hurry! Tell me yes or no''')
    power = input(prompt = f'{name}:\n\t--> ')
    
    if "yes" in power:
        print('''
Monster:
\tThere you go, eat them and you will fill the power soon
\ttake my card so we can talk later, I'm part of the
\tMonster Association''')     
        header()
        fail()
    else:
        print('''
Monster:
\tOk, if you are not interested get lost. I don't have 
\ttime to waste on you, unless you want to die!''')
        time.sleep(1)
        print('''\n\n
                ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠛⠛⠉⠉⠉⠉⠉⠉⠛⠻⢿⣿⣿⣿⣿⣿⣿
                ⣿⣿⣿⣿⣿⣿⣿⡿⠋⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣿⣿⣿⣿
                ⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣿⣿
                ⣿⣿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣿⣿
                ⣿⣿⣿⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿
                ⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⣿
                ⣿⣿⣿⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
                ⣿⣿⣿⣿⠀⠀⠀⠀⠀⢠⡴⠶⠶⠶⠶⠄⠀⠀⠀⠀⠀⠴⠶⠶⠤⠀⢠⡿
                ⣿⣿⣿⣿⣄⠀⠀⠀⠀⠀⢀⣀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿
                ⣿⣿⢋⣽⣿⠷⠀⠀⠀⡞⠁⠀⢀⠈⠉⠦⠀⠀⢠⣠⡞⠉⡉⠉⠳⠄⣼⣿
                ⣿⣿⢸⣿⣿⡇⠀⠀⠀⠳⣄⡀⠀⢀⡠⠃⠀⠀⣼⠉⢧⣀⣀⣠⠴⠀⣿⣿
                ⠇⢻⣿⣿⣿⡄⠀⠀⠀⠀⠀⠉⠉⠀⠀⠀⠀⠀⣿⡆⠀⠈⠁⠀⠀⢀⣿⣿
                ⠀⢸⣿⣷⣦⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠇⠀⠀⠀⠀⠀⢸⣿⣿
                ⠀⢸⣿⣿⣿⣿⣇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠀⠀⠀⠀⢀⣿⣿⣿
                ⣶⣾⣿⣿⣿⣿⣿⡆⠀⠀⠀⠀⠀⠀⢠⣤⣤⣄⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿
                ⣿⣿⣿⣿⣿⣿⣿⣿⣄⠀⠀⠀⠀⠀⠀⠙⠛⠋⠀⠀⠀⠀⠀⣼⣿⣿⣿⣿
                ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⣿⣿⣿⣿⣿
                ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣶⣤⣀⣀⣀⣠⣤⣶⣾⣿⣿⣿⣿⣿⣿⣿
                
Saitama:
\tHey! I just killed that monster that was offering you those
\tmonster cells, good that you didn't turned into a monster right. 
\tLet me tell you something... The true power of us human beings 
\tis that we can change ourselves on our own. 
\tSon don't let monsters change you!\n
''')
        header()
        fail()
    
################################################################################################################

def fail():
    print('\nWell that was a crazy day...\n')
    restart = input('Would like to play again? Yes/No\t')
    if 'yes' in restart.lower():
        start()
    elif 'no' in restart.lower():
        print(f'\n{close}')
    else:
        print(f'\nSince you are typing random stuff we assume it\'s a no\n{close}')

menu()
# Out:
# 		███╗   ███╗███████╗███╗   ██╗██╗   ██╗
# 		████╗ ████║██╔════╝████╗  ██║██║   ██║
# 		██╔████╔██║█████╗  ██╔██╗ ██║██║   ██║
# 		██║╚██╔╝██║██╔══╝  ██║╚██╗██║██║   ██║
# 		██║ ╚═╝ ██║███████╗██║ ╚████║╚██████╔╝
# 		╚═╝     ╚═╝╚══════╝╚═╝  ╚═══╝ ╚═════╝
#
#
# 			   1) Instructions
# 			   2) Start Game
# 			   3) Credits
# 			   4) Quit
#
# 		-->2
#
#
# --------------------------------------------------------------------------------
#
#
#
# 		>>>>> HERO TEST LOCATION 6 <<<<<
#
#
# Recruiter:
# 	Candidates, please form two lines for registration...
#
# 		<Press any key to continue>
#
#
# Recruiter:
# 	We are glad you came, it's always great to see a bunch of
# 	people come to be part of the Hero Assosiation... well I
# 	should't talk that much.
# 	What's your Superhero name?	--> beastmaster69
#
# Recruiter:
# 	beastmaster69 mmmmm... interesting name for a Superhero.
# 	Now plese tell us the name of your special attack...	--> jan ken pu
#
# Recruiter:
# ...

# %%
w
